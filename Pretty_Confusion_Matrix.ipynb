# %%
pip install pretty-confusion-matrix
# Out:
# Collecting pretty-confusion-matrix
#   Downloading pretty_confusion_matrix-0.1.1-py3-none-any.whl (9.6 kB)
# Collecting matplotlib<4.0.0,>=3.5.0
#   Downloading matplotlib-3.5.3-cp38-cp38-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 32.8 MB/s eta 0:00:00
# Collecting black<22.0,>=21.5b0
#   Downloading black-21.12b0-py3-none-any.whl (156 kB)
#      ---------------------------------------- 156.7/156.7 kB ? eta 0:00:00
# Collecting flake8<4.0.0,>=3.9.2
#   Downloading flake8-3.9.2-py2.py3-none-any.whl (73 kB)
#      ---------------------------------------- 73.1/73.1 kB ? eta 0:00:00
# Requirement already satisfied: sklearn<0.1,>=0.0 in c:\python38\lib\site-packages (from pretty-confusion-matrix) (0.0)
# Requirement already satisfied: seaborn<0.12.0,>=0.11.2 in c:\python38\lib\site-packages (from pretty-confusion-matrix) (0.11.2)
# Collecting pre-commit<3.0.0,>=2.12.1
#   Downloading pre_commit-2.20.0-py2.py3-none-any.whl (199 kB)
#      ------------------------------------- 199.5/199.5 kB 11.8 MB/s eta 0:00:00
# Collecting isort<6.0.0,>=5.8.0
#   Using cached isort-5.10.1-py3-none-any.whl (103 kB)
# Collecting numpy<2.0.0,>=1.21.4
#   Downloading numpy-1.23.2-cp38-cp38-win_amd64.whl (14.7 MB)
#      --------------------------------------- 14.7/14.7 MB 50.3 MB/s eta 0:00:00
# Collecting pandas<2.0.0,>=1.3.4
#   Downloading pandas-1.4.4-cp38-cp38-win_amd64.whl (10.6 MB)
#      --------------------------------------- 10.6/10.6 MB 26.2 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.1.2 in c:\python38\lib\site-packages (from black<22.0,>=21.5b0->pretty-confusion-matrix) (7.1.2)
# Collecting tomli<2.0.0,>=0.2.6
#   Downloading tomli-1.2.3-py3-none-any.whl (12 kB)
# Collecting pathspec<1,>=0.9.0
#   Downloading pathspec-0.10.1-py3-none-any.whl (27 kB)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting platformdirs>=2
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Collecting typing-extensions>=3.10.0.0
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Collecting pycodestyle<2.8.0,>=2.7.0
#   Downloading pycodestyle-2.7.0-py2.py3-none-any.whl (41 kB)
#      ---------------------------------------- 41.7/41.7 kB ? eta 0:00:00
# Collecting pyflakes<2.4.0,>=2.3.0
#   Downloading pyflakes-2.3.1-py2.py3-none-any.whl (68 kB)
#      ---------------------------------------- 68.8/68.8 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in c:\users\agamm\appdata\roaming\python\python38\site-packages (from flake8<4.0.0,>=3.9.2->pretty-confusion-matrix) (0.6.1)
# Requirement already satisfied: packaging>=20.0 in c:\python38\lib\site-packages (from matplotlib<4.0.0,>=3.5.0->pretty-confusion-matrix) (20.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python38\lib\site-packages (from matplotlib<4.0.0,>=3.5.0->pretty-confusion-matrix) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python38\lib\site-packages (from matplotlib<4.0.0,>=3.5.0->pretty-confusion-matrix) (1.2.0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.37.1-py3-none-any.whl (957 kB)
#      ------------------------------------- 957.2/957.2 kB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\python38\lib\site-packages (from matplotlib<4.0.0,>=3.5.0->pretty-confusion-matrix) (2.8.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pillow>=6.2.0 in c:\python38\lib\site-packages (from matplotlib<4.0.0,>=3.5.0->pretty-confusion-matrix) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\python38\lib\site-packages (from matplotlib<4.0.0,>=3.5.0->pretty-confusion-matrix) (0.10.0)
# Requirement already satisfied: pytz>=2020.1 in c:\python38\lib\site-packages (from pandas<2.0.0,>=1.3.4->pretty-confusion-matrix) (2020.1)
# Collecting virtualenv>=20.0.8
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
#     WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
#     WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
#     WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
#     WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
#     WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# deepface 0.0.33 requires Flask>=1.1.2, but you have flask 1.0.2 which is incompatible.
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\python38\lib\site-packages)
#   Downloading virtualenv-20.16.5-py3-none-any.whl (8.8 MB)
#      ---------------------------------------- 8.8/8.8 MB 51.1 MB/s eta 0:00:00
# Requirement already satisfied: toml in c:\users\agamm\appdata\roaming\python\python38\site-packages (from pre-commit<3.0.0,>=2.12.1->pretty-confusion-matrix) (0.10.2)
# Collecting nodeenv>=0.11.1
#   Downloading nodeenv-1.7.0-py2.py3-none-any.whl (21 kB)
# Collecting cfgv>=2.0.0
#   Downloading cfgv-3.3.1-py2.py3-none-any.whl (7.3 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\python38\lib\site-packages (from pre-commit<3.0.0,>=2.12.1->pretty-confusion-matrix) (5.3.1)
# Collecting identify>=1.0.0
#   Downloading identify-2.5.5-py2.py3-none-any.whl (98 kB)
#      ---------------------------------------- 98.7/98.7 kB ? eta 0:00:00
# Requirement already satisfied: scipy>=1.0 in c:\python38\lib\site-packages (from seaborn<0.12.0,>=0.11.2->pretty-confusion-matrix) (1.4.1)
# Requirement already satisfied: scikit-learn in c:\python38\lib\site-packages (from sklearn<0.1,>=0.0->pretty-confusion-matrix) (1.0.2)
# Requirement already satisfied: six in c:\python38\lib\site-packages (from cycler>=0.10->matplotlib<4.0.0,>=3.5.0->pretty-confusion-matrix) (1.15.0)
# Requirement already satisfied: setuptools in c:\python38\lib\site-packages (from nodeenv>=0.11.1->pre-commit<3.0.0,>=2.12.1->pretty-confusion-matrix) (49.2.0)
# Collecting filelock<4,>=3.4.1
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Collecting distlib<1,>=0.3.5
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ------------------------------------- 468.5/468.5 kB 28.6 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python38\lib\site-packages (from scikit-learn->sklearn<0.1,>=0.0->pretty-confusion-matrix) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\python38\lib\site-packages (from scikit-learn->sklearn<0.1,>=0.0->pretty-confusion-matrix) (0.16.0)
# Installing collected packages: mypy-extensions, distlib, typing-extensions, tomli, pyflakes, pycodestyle, platformdirs, pathspec, numpy, nodeenv, isort, identify, fonttools, filelock, cfgv, virtualenv, pandas, matplotlib, flake8, black, pre-commit, pretty-confusion-matrix
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.0
#     Uninstalling numpy-1.19.0:
#       Successfully uninstalled numpy-1.19.0
#   Attempting uninstall: isort
#     Found existing installation: isort 5.6.4
#     Uninstalling isort-5.6.4:
#       Successfully uninstalled isort-5.6.4
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.0.12
#     Uninstalling filelock-3.0.12:
#       Successfully uninstalled filelock-3.0.12
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.0.3
#     Uninstalling pandas-1.0.3:
#       Successfully uninstalled pandas-1.0.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.3.0
#     Uninstalling matplotlib-3.3.0:
#       Successfully uninstalled matplotlib-3.3.0
# Successfully installed black-21.12b0 cfgv-3.3.1 distlib-0.3.6 filelock-3.8.0 flake8-3.9.2 fonttools-4.37.1 identify-2.5.5 isort-5.10.1 matplotlib-3.5.3 mypy-extensions-0.4.3 nodeenv-1.7.0 numpy-1.23.2 pandas-1.4.4 pathspec-0.10.1 platformdirs-2.5.2 pre-commit-2.20.0 pretty-confusion-matrix-0.1.1 pycodestyle-2.7.0 pyflakes-2.3.1 tomli-1.2.3 typing-extensions-4.3.0 virtualenv-20.16.5
#
# [notice] A new release of pip available: 22.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from pretty_confusion_matrix import pp_matrix
import matplotlib.pyplot as plt

# %%
array = np.array([[341755,    340,       791,    455,         4065,          4579,    5776,      111,    370],
                  [   146,   2141,         0,      0,            0,             1,       0,        0,      0],
                  [    69,      0,       200,      0,            0,             0,       0,        0,      0],
                  [  1916,      1,         0,   2965,            0,             4,       0,        0,     16],
                  [   625,      0,         0,      3,          895,           409,     311,        0,      0],
                  [   103,      1,         0,     16,            1,         28364,      40,       18,      2],
                  [     7,      0,         0,      0,          282,           133,    4633,        0,      0],
                  [   393,      0,         0,      3,            0,             0,       0,      235,      1],
                  [   934,      1,         0,    268,            0,             8,       0,        6,     36]])

# get pandas dataframe
labels = ["pred","entity_1", "entity_2", "entity_3", "entity_4", "entity_5","entity_6", "entity_7", "entity_8"]
pred = ["true","entity_1", "entity_2", "entity_3", "entity_4", "entity_5","entity_6", "entity_7", "entity_8"]

df_cm = pd.DataFrame(array, index=labels, columns=pred)

cmap = 'gist_yarg_r'
# plt.figure(figsize=(102, 12))

pp_matrix(df_cm, cmap=cmap, figsize=(10, 10))

# %%
array = np.array([[356856,        17 ,        3,         159,         182,        426,        386,        10,         203],
                  [  911  ,       1377,       0 ,        0   ,        0   ,       0   ,       0   ,       0  ,        0   ],
                  [  107   ,      0    ,      116,       0    ,       0    ,      0    ,      0    ,      0   ,       0    ],
                  [ 1924    ,     0     ,     0   ,      2866  ,      0     ,     0     ,     0     ,     3     ,     9     ],
                  [ 1289     ,    0      ,    0    ,     0      ,     654    ,    131    ,    366    ,    1      ,    0      ],
                  [ 4693      ,   3       ,   0     ,    19      ,    7       ,   23784   ,   31      ,   3       ,   5       ],
                  [ 1530       ,  0        ,  0      ,   0        ,   27       ,  59       ,  3439     ,  0        ,  0        ],
                  [  586        , 0         , 0        , 0         ,  0         , 0         , 0         , 46        , 0         ],
                  [  966         ,0          ,0         ,3           ,0          ,0          ,0          ,0          ,14         ]])

# get pandas dataframe
labels = ["pred","entity_1", "entity_2", "entity_3", "entity_4", "entity_5","entity_6", "entity_7", "entity_8"]
pred = ["true","entity_1", "entity_2", "entity_3", "entity_4", "entity_5","entity_6", "entity_7", "entity_8"]

df_cm = pd.DataFrame(array, index=labels, columns=pred)

cmap = 'gist_yarg_r'
# plt.figure(figsize=(102, 12))

pp_matrix(df_cm, cmap=cmap, figsize=(10, 10))
